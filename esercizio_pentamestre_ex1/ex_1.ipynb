# %% [markdown]
# # Foglio Esercizi 1

# %% [markdown]
# ### Ex 1: Crea una funzione che prende in input una matrice e stampa elemento per elemento

# %%
import utils

A = [[1, 2, 3], [4, 5, 6]]
utils.stampa_matrice(A)
# Out:
# 1	2	3	4	5	6

# %% [markdown]
# ### Ex 2: Crea una funzione che prende in input una matrice e restituisce la somma dei suoi elementi

# %%
import utils


A = [[1, 2, 3], [1, 2, 3]]
s = utils.somma_matrice(A)
print(s)

# %% [markdown]
# ### Ex 3: Crea una funzione che prende in input una matrice e restituisce l'elemento minimo

# %%
import utils


A = [[1, 2, 3], [5, -3, 4]]
m = utils.min_matrice(A)
print(m)

# %% [markdown]
# ### Ex 4: Crea una funzione che prende in input una matrice quadrata e stampa gli elementi lungo la diagonale

# %%
import utils

A = [[2, 3], [4, 5]]
utils.diag_matrice(A)

# %% [markdown]
# ### Ex 5: Crea una funzione che prende in input una matrice e stampa la somma di ogni riga

# %%
import utils

A = [[1, 2, 3], [1, 2, -3]]
utils.somma_righe(A)
