# %% [markdown]
# # Foglio Esercizi 7

# %% [markdown]
# ### Ex 1: Scrivi una funzione che prende in input una matrice e restituisce il valore medio

# %% [markdown]
# ### Ex 2: Scrivi una funzione che prende in input una matrice e restituisce la somma degli elementi sul bordo

# %% [markdown]
# ### Ex 3: Scrivi una funzione che prende in input una matrice e restituisce la somma delle righe pari meno la somma delle righe dispari

# %% [markdown]
# ### Ex 4: Scrivi una funzione che prende in input una matrice e restituisce la differenza tra gli elementi sopra la diagonale e gli elementi sotto la diagonale

# %% [markdown]
# ### Ex 5: Scrivi una funzione che prende in input una matrice e un indice e setta a zero tutti gli elementi di tale riga
