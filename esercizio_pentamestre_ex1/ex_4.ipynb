# %% [markdown]
# # Foglio Esercizi 4

# %% [markdown]
# ### Ex 1: prodotto della somma delle diagonali

# %%
import numpy as np
import utils
A=np.array([[1,2],[3,4]])
m=utils.fun_1_es_4(A)
print(m)

# %% [markdown]
# ### Ex 2: scambio di due righe

# %%
import numpy as np
def fun_2_es_4(A:np.ndarray):
    for i in range(A.shape[0]):
        for j in range(A.shape[0]):

# %% [markdown]
# ### Ex 3: Scambio di due colonne

# %% [markdown]
# ### Ex 4: Prodotto matrice vettore

# %% [markdown]
# ### Ex 5: Prodotto di due matrici
