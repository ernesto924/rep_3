# %% [markdown]
# # Foglio Esercizi 5

# %% [markdown]
# ### Ex 1: Scrivi una funzione che prende una matrice e restituisce la riga di somma massima

# %%
import numpy as np
import utils
A=np.ndarray([2,3],[4,5])
max=utils.fun_es_5(A)
print(max)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import numpy as np
#       2 import utils
# ----> 3 A=np.ndarray([2,3],[4,5])
#       4 max=utils.fun_es_5(A)
#       5 print(max)
#
# TypeError: Field elements must be 2- or 3-tuples, got '4'

# %% [markdown]
# ### Ex 2: Scrivi una funzione che prende in input una matrice e restituisce la colonna di somma massima

# %% [markdown]
# ### Ex 3: Scrivi una funzione che prende in input una matrice e resituisce la matrice normalizzata per righe

# %% [markdown]
# ### Ex 4: Scrivi una funzione che prende in input una matrice e resituisce la matrice normalizzata per colonne

# %% [markdown]
# ### Ex 5: Scrivi una funzione che prende in input una matrice e resituisce la matrice normalizzata
