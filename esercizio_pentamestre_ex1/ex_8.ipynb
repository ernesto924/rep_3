# %% [markdown]
# # Foglio Esercizi 8

# %% [markdown]
# ### Ex 1: Somma degli elementi sulla anti-diagonale

# %%
import numpy as np
a=np.ndarray([1,3,5,0,7,8,0])
for i in range(a.shape[0]):
    if[a(0)]

# %% [markdown]
# ### Ex 2: Restituisce la somma dei vertici

# %% [markdown]
# ### Ex 3: Aggiunge un bordo di zeri attorno alla matrice di spessore indicato

# %% [markdown]
# ### Ex 4: Shift circolare delle righe verso il basso di k posizioni

# %% [markdown]
# ### Ex 5: Restituisce una matrice ruotata di 90 gradi in senso orario
