# %% [markdown]
# # Foglio Esercizi 6

# %% [markdown]
# ### Ex 1: Scrivi una funzione che prende in input una matrice di interi e cambia il segno a tutti gli elementi pari

# %% [markdown]
# ### Ex 2: Scrivi una funzione che prende in input una matrice e restituisce il numero di elementi multipli di tre

# %% [markdown]
# ### Ex 3: Scrivi una funzione che prende in input una matrice e restituisce la somma di tutte le righe

# %%
import numpy as np
def fun_6_3(A:np.ndarray):
    somma=0
    b=[]
    for i in range(A.shape[1]):
        for j in range(A.shape[0]):
            somma=somma+A[i][j]
            b.appened(somma)
    return b

# %% [markdown]
# ### Ex 4: Scrivi una funzione che prende in input una matrice e restituisce la somma di tutte le colonne

# %% [markdown]
# ### Ex 5: Scrivi una funzione che prende in input una matrice e restituisce un array con elementi il massimo della riga corrispondente

# %% [markdown]
# ### Ex 6: Scrivi una funzione che prende in input una matrice e restituisce un array con elementi il massimo della colonna corrispondente
